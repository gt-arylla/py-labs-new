# %%
import pandas as pd
df=pd.read_csv("Adder_File_2.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-cf17eaacea94> in <module>()
# ----> 1 import pandas as pd
#       2 df=pd.read_csv("Adder_File_2.csv")
#
# C:\Users\gttho\Anaconda2\lib\site-packages\pandas\__init__.py in <module>()
#      29                       "pandas from the source directory, you may need to run "
#      30                       "'python setup.py build_ext --inplace --force' to build "
# ---> 31                       "the C extensions first.".format(module))
#      32
#      33 from datetime import datetime
#
# ImportError: C extension: hashtable not built. If you want to import pandas from the source directory, you may need to run 'python setup.py build_ext --inplace --force' to build the C extensions first.

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.loc[~df['ROI_0_scan_0'].str.contains('#NAME?')]
# Out:
#          DateTime                    Formulation  Ink  Binder  Solvent  \
# 0    2.017120e+13   S.FM1 - 50/50-C - PM19987b62  NaN     NaN      NaN
# 1    2.017120e+13   S.FM1 - 50/50-C - PM6a5e6d16  NaN     NaN      NaN
# 2    2.017120e+13   S.FM1 - 50/50-C - PMe110a572  NaN     NaN      NaN
# 3    2.017120e+13   S.FM1 - 50/50-C - PMffc67300  NaN     NaN      NaN
# 4    2.017120e+13   S.FM1 - 50/50-C - PM55c654c8  NaN     NaN      NaN
# 5    2.017120e+13   S.FM1 - 50/50-C - PM369a2b46  NaN     NaN      NaN
# 6    2.017120e+13   S.FM1 - 50/50-C - PM44904676  NaN     NaN      NaN
# 7    2.017120e+13   S.FM1 - 50/50-C - PM357bd76b  NaN     NaN      NaN
# 8    2.017120e+13   S.FM1 - 50/50-C - PM38444f48  NaN     NaN      NaN
# 9    2.017120e+13   P.FM1 - 50/50-C - PM1a5bf38f  3.5    66.5     30.0
# 10   2.017120e+13   P.FM1 - 50/50-C - PM71efb4c8  3.5    66.5     30.0
# 11   2.017120e+13   P.FM1 - 50/50-C - PM09be57c8  3.5    66.5     30.0
# ...

# %%
import copy
df2=copy.copy(df)

# %%
header_list=df.columns.values.tolist()
#print type(header_list[10])

#print header_list
for header in header_list:
    #print df2[header]
    try:
        df2=df2.loc[~df2[header].str.contains('#NAME?')]
    except:
        null=1
import numpy as np
df2.applymap(np.isreal)
# Out:
#     DateTime Formulation   Ink Binder Solvent ROI_0_PrintValue  \
# 0       True       False  True   True    True            False
# 1       True       False  True   True    True            False
# 2       True       False  True   True    True            False
# 3       True       False  True   True    True            False
# 4       True       False  True   True    True            False
# 5       True       False  True   True    True            False
# 6       True       False  True   True    True            False
# 7       True       False  True   True    True            False
# 8       True       False  True   True    True            False
# 9       True       False  True   True    True            False
# 11      True       False  True   True    True            False
# 12      True       False  True   True    True            False
# 13      True       False  True   True    True            False
# 14      True       False  True   True    True            False
# ...

# %%
~df['ROI_0_scan_0'].str.contains('#NAME?')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
#        ...
# 513    True
# 514    True
# 515    True
# 516    True
# 517    True
# 518    True
# 519    True
# 520    True
# 521    True
# 522    True
# 523    True
# 524    True
# 525    True
# 526    True
# 527    True
# 528    True
# 529    True
# 530    True
# 531    True
# 532    True
# 533    True
# 534    True
# 535    True
# 536    True
# 537    True
# 538    True
# 539    True
# 540    True
# 541    True
# 542    True
# Name: ROI_0_scan_0, dtype: bool

# %%
import numpy as np
df.applymap(np.isreal)
# Out:
#     DateTime Formulation   Ink Binder Solvent ROI_0_PrintValue  \
# 0       True       False  True   True    True            False
# 1       True       False  True   True    True            False
# 2       True       False  True   True    True            False
# 3       True       False  True   True    True            False
# 4       True       False  True   True    True            False
# 5       True       False  True   True    True            False
# 6       True       False  True   True    True            False
# 7       True       False  True   True    True            False
# 8       True       False  True   True    True            False
# 9       True       False  True   True    True            False
# 10      True       False  True   True    True            False
# 11      True       False  True   True    True            False
# 12      True       False  True   True    True            False
# 13      True       False  True   True    True            False
# ...

# %%
pd.to_numeric(convert_numeric=True).dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-c4b1e6ec8564> in <module>()
# ----> 1 df.to_numeric(convert_numeric=True).dtype
#
# C:\Users\gttho\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_numeric'

# %%
df3=copy.copy(df)
header_list=df.columns.values.tolist()
for index in range(5,len(header_list)):
    df3[header_list[index]] = df3[header_list[index]].apply(pd.to_numeric,errors='coerce')
df3
import numpy as np
#df3 = df3[pd.notnull(df['EPS'])]
df3.dropna(subset = header_list[2:])
# Out:
#          DateTime                    Formulation  Ink  Binder  Solvent  \
# 9    2.017120e+13   P.FM1 - 50/50-C - PM1a5bf38f  3.5    66.5     30.0
# 11   2.017120e+13   P.FM1 - 50/50-C - PM09be57c8  3.5    66.5     30.0
# 12   2.017120e+13   P.FM1 - 50/50-C - PM2de2ab06  3.5    66.5     30.0
# 13   2.017120e+13   P.FM1 - 50/50-C - PM79fbd6f9  3.5    66.5     30.0
# 14   2.017120e+13   P.FM1 - 50/50-C - PMfc96238b  3.5    66.5     30.0
# 15   2.017120e+13   P.FM1 - 50/50-C - PMab181cd9  3.5    66.5     30.0
# 16   2.017120e+13   P.FM1 - 50/50-C - PM9fc27f5c  3.5    66.5     30.0
# 17   2.017120e+13   P.FM1 - 50/50-C - PM37875a01  3.5    66.5     30.0
# 19   2.017120e+13   P.FM1 - 50/50-C - PM13dbcef2  3.0    67.0     30.0
# 20   2.017120e+13   P.FM1 - 50/50-C - PMce93af3b  3.0    67.0     30.0
# 21   2.017120e+13   P.FM1 - 50/50-C - PMf2123a9e  3.0    67.0     30.0
# 22   2.017120e+13   P.FM1 - 50/50-C - PMda9e39b9  3.0    67.0     30.0
# ...

# %%
df4=df[['Ink','Solvent']]
df4
# Out:
#      Ink  Solvent
# 0    NaN      NaN
# 1    NaN      NaN
# 2    NaN      NaN
# 3    NaN      NaN
# 4    NaN      NaN
# 5    NaN      NaN
# 6    NaN      NaN
# 7    NaN      NaN
# 8    NaN      NaN
# 9    3.5     30.0
# 10   3.5     30.0
# 11   3.5     30.0
# 12   3.5     30.0
# 13   3.5     30.0
# 14   3.5     30.0
# 15   3.5     30.0
# 16   3.5     30.0
# 17   3.5     30.0
# 18   3.5     30.0
# 19   3.0     30.0
# 20   3.0     30.0
# 21   3.0     30.0
# 22   3.0     30.0
# 23   3.0     30.0
# 24   3.0     30.0
# 25   3.0     30.0
# 26   3.0     30.0
# 27   3.0     30.0
# 28   3.0     30.0
# 29   4.0     28.0
# ..   ...      ...
# 513  4.0     28.0
# 514  4.0     28.0
# 515  4.0     28.0
# 516  4.0     28.0
# 517  4.0     28.0
# 518  4.0     28.0
# 519  4.0     28.0
# 520  1.0     10.0
# 521  1.0     10.0
# 522  1.0     10.0
# 523  1.0     10.0
# 524  1.0     10.0
# 525  1.0     10.0
# 526  1.5     10.0
# 527  1.5     10.0
# 528  1.5     10.0
# 529  0.0      0.0
# 530  0.0      0.0
# ...

# %%
import itertools as it
numbers=[1,2,3,4]
data_cols=[2,3,4,7]
for number in numbers:
    for combos in it.combinations(data_cols,number):
        print list(combos)
# Out:
# [2]
# [3]
# [4]
# [7]
# [2, 3]
# [2, 4]
# [2, 7]
# [3, 4]
# [3, 7]
# [4, 7]
# [2, 3, 4]
# [2, 3, 7]
# [2, 4, 7]
# [3, 4, 7]
# [2, 3, 4, 7]
